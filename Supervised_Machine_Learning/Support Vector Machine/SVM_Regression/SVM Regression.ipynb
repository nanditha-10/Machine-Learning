# %%
  
# necessary Imports
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Admission_Prediction.csv')

# %%
print(df.head())
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1      337.0        118.0                4.0  4.5  4.5  9.65
# 1           2      324.0        107.0                4.0  4.0  4.5  8.87
# 2           3        NaN        104.0                3.0  3.0  3.5  8.00
# 3           4      322.0        110.0                3.0  3.5  2.5  8.67
# 4           5      314.0        103.0                2.0  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
print(df.isna().sum())
# Out:
# Serial No.            0
# GRE Score            15
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
# As we can see, there are some column with missing values. we need to impute those missing values.
df['GRE Score'].fillna(df['GRE Score'].mean(),inplace=True)
df['TOEFL Score'].fillna(df['TOEFL Score'].mean(),inplace=True)
df['University Rating'].fillna(df['University Rating'].mode()[0],inplace=True)
# Out:
# C:\Users\ANANDITH\AppData\Local\Temp\ipykernel_27100\182111347.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GRE Score'].fillna(df['GRE Score'].mean(),inplace=True)
# C:\Users\ANANDITH\AppData\Local\Temp\ipykernel_27100\182111347.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TOEFL Score'].fillna(df['TOEFL Score'].mean(),inplace=True)
# C:\Users\ANANDITH\AppData\Local\Temp\ipykernel_27100\182111347.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['University Rating'].fillna(df['University Rating'].mode()[0],inplace=True)

# %%
# seeing that after imputation no column has missing values
print(df.isna().sum())
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
x=df.drop(['Chance of Admit','Serial No.'],axis=1)
y=df['Chance of Admit']
columns=x.columns

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.33, random_state=33)

# %%
from sklearn.svm import SVR
svr= SVR(C=10)

# %%
svr.fit(train_x, train_y)
# Out:
# SVR(C=10)

# %%
from sklearn.metrics import r2_score
score= r2_score(test_y,svr.predict(test_x))
print(score)
# Out:
# 0.7340987165302327

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.1,1,10,50,100,500],'gamma':[1,0.5,0.1,0.01,0.001] }
grid= GridSearchCV(SVR(),param_grid, verbose=3)

# %%
grid.fit(train_x,train_y)
grid.best_estimator_
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.092 total time=   0.0s
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.126 total time=   0.0s
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.079 total time=   0.0s
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.089 total time=   0.0s
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.054 total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.5;, score=0.232 total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=0.5;, score=0.271 total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.5;, score=0.204 total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=0.5;, score=0.193 total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.5;, score=0.141 total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.550 total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.623 total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.598 total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.380 total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.415 total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=0.01;, score=0.670 total time=   0.0s
# [CV 2/5] END .................C=0.1, gamma=0.01;, score=0.711 total time=   0.0s
# [CV 3/5] END .................C=0.1, gamma=0.01;, score=0.748 total time=   0.0s
# [CV 4/5] END .................C=0.1, gamma=0.01;, score=0.439 total time=   0.0s
# [CV 5/5] END .................C=0.1, gamma=0.01;, score=0.663 total time=   0.0s
# [CV 1/5] END ................C=0.1, gamma=0.001;, score=0.681 total time=   0.0s
# [CV 2/5] END ................C=0.1, gamma=0.001;, score=0.693 total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=0.001;, score=0.763 total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=0.001;, score=0.452 total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=0.001;, score=0.665 total time=   0.0s
# [CV 1/5] END ......................C=1, gamma=1;, score=0.124 total time=   0.0s
# [CV 2/5] END ......................C=1, gamma=1;, score=0.123 total time=   0.0s
# [CV 3/5] END ......................C=1, gamma=1;, score=0.093 total time=   0.0s
# [CV 4/5] END ......................C=1, gamma=1;, score=0.111 total time=   0.0s
# [CV 5/5] END ......................C=1, gamma=1;, score=0.064 total time=   0.0s
# [CV 1/5] END ....................C=1, gamma=0.5;, score=0.281 total time=   0.0s
# [CV 2/5] END ....................C=1, gamma=0.5;, score=0.284 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.5;, score=0.239 total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.5;, score=0.199 total time=   0.0s
# [CV 5/5] END ....................C=1, gamma=0.5;, score=0.144 total time=   0.0s
# [CV 1/5] END ....................C=1, gamma=0.1;, score=0.571 total time=   0.0s
# [CV 2/5] END ....................C=1, gamma=0.1;, score=0.626 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.635 total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.1;, score=0.346 total time=   0.0s
# [CV 5/5] END ....................C=1, gamma=0.1;, score=0.399 total time=   0.0s
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.698 total time=   0.0s
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.723 total time=   0.0s
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.782 total time=   0.0s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.444 total time=   0.0s
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.663 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.735 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.718 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.796 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.481 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.740 total time=   0.0s
# [CV 1/5] END .....................C=10, gamma=1;, score=0.124 total time=   0.0s
# [CV 2/5] END .....................C=10, gamma=1;, score=0.123 total time=   0.0s
# [CV 3/5] END .....................C=10, gamma=1;, score=0.093 total time=   0.0s
# [CV 4/5] END .....................C=10, gamma=1;, score=0.111 total time=   0.0s
# [CV 5/5] END .....................C=10, gamma=1;, score=0.064 total time=   0.0s
# [CV 1/5] END ...................C=10, gamma=0.5;, score=0.281 total time=   0.0s
# [CV 2/5] END ...................C=10, gamma=0.5;, score=0.284 total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=0.5;, score=0.239 total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=0.5;, score=0.199 total time=   0.0s
# [CV 5/5] END ...................C=10, gamma=0.5;, score=0.144 total time=   0.0s
# [CV 1/5] END ...................C=10, gamma=0.1;, score=0.571 total time=   0.0s
# [CV 2/5] END ...................C=10, gamma=0.1;, score=0.626 total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=0.1;, score=0.635 total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=0.1;, score=0.346 total time=   0.0s
# [CV 5/5] END ...................C=10, gamma=0.1;, score=0.399 total time=   0.0s
# [CV 1/5] END ..................C=10, gamma=0.01;, score=0.662 total time=   0.0s
# [CV 2/5] END ..................C=10, gamma=0.01;, score=0.735 total time=   0.0s
# [CV 3/5] END ..................C=10, gamma=0.01;, score=0.722 total time=   0.0s
# [CV 4/5] END ..................C=10, gamma=0.01;, score=0.383 total time=   0.0s
# [CV 5/5] END ..................C=10, gamma=0.01;, score=0.567 total time=   0.0s
# [CV 1/5] END .................C=10, gamma=0.001;, score=0.768 total time=   0.0s
# [CV 2/5] END .................C=10, gamma=0.001;, score=0.722 total time=   0.0s
# [CV 3/5] END .................C=10, gamma=0.001;, score=0.824 total time=   0.0s
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.545 total time=   0.0s
# [CV 5/5] END .................C=10, gamma=0.001;, score=0.768 total time=   0.0s
# [CV 1/5] END .....................C=50, gamma=1;, score=0.124 total time=   0.0s
# [CV 2/5] END .....................C=50, gamma=1;, score=0.123 total time=   0.0s
# [CV 3/5] END .....................C=50, gamma=1;, score=0.093 total time=   0.0s
# [CV 4/5] END .....................C=50, gamma=1;, score=0.111 total time=   0.0s
# [CV 5/5] END .....................C=50, gamma=1;, score=0.064 total time=   0.0s
# [CV 1/5] END ...................C=50, gamma=0.5;, score=0.281 total time=   0.0s
# [CV 2/5] END ...................C=50, gamma=0.5;, score=0.284 total time=   0.0s
# [CV 3/5] END ...................C=50, gamma=0.5;, score=0.239 total time=   0.0s
# [CV 4/5] END ...................C=50, gamma=0.5;, score=0.199 total time=   0.0s
# [CV 5/5] END ...................C=50, gamma=0.5;, score=0.144 total time=   0.0s
# [CV 1/5] END ...................C=50, gamma=0.1;, score=0.571 total time=   0.0s
# [CV 2/5] END ...................C=50, gamma=0.1;, score=0.626 total time=   0.0s
# [CV 3/5] END ...................C=50, gamma=0.1;, score=0.635 total time=   0.0s
# [CV 4/5] END ...................C=50, gamma=0.1;, score=0.346 total time=   0.0s
# [CV 5/5] END ...................C=50, gamma=0.1;, score=0.399 total time=   0.0s
# [CV 1/5] END ..................C=50, gamma=0.01;, score=0.659 total time=   0.0s
# [CV 2/5] END ..................C=50, gamma=0.01;, score=0.726 total time=   0.0s
# [CV 3/5] END ..................C=50, gamma=0.01;, score=0.681 total time=   0.0s
# [CV 4/5] END ..................C=50, gamma=0.01;, score=0.235 total time=   0.0s
# [CV 5/5] END ..................C=50, gamma=0.01;, score=0.537 total time=   0.0s
# [CV 1/5] END .................C=50, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 2/5] END .................C=50, gamma=0.001;, score=0.728 total time=   0.0s
# [CV 3/5] END .................C=50, gamma=0.001;, score=0.834 total time=   0.0s
# [CV 4/5] END .................C=50, gamma=0.001;, score=0.586 total time=   0.0s
# [CV 5/5] END .................C=50, gamma=0.001;, score=0.755 total time=   0.0s
# [CV 1/5] END ....................C=100, gamma=1;, score=0.124 total time=   0.0s
# [CV 2/5] END ....................C=100, gamma=1;, score=0.123 total time=   0.0s
# [CV 3/5] END ....................C=100, gamma=1;, score=0.093 total time=   0.0s
# [CV 4/5] END ....................C=100, gamma=1;, score=0.111 total time=   0.0s
# [CV 5/5] END ....................C=100, gamma=1;, score=0.064 total time=   0.0s
# [CV 1/5] END ..................C=100, gamma=0.5;, score=0.281 total time=   0.0s
# [CV 2/5] END ..................C=100, gamma=0.5;, score=0.284 total time=   0.0s
# [CV 3/5] END ..................C=100, gamma=0.5;, score=0.239 total time=   0.0s
# [CV 4/5] END ..................C=100, gamma=0.5;, score=0.199 total time=   0.0s
# [CV 5/5] END ..................C=100, gamma=0.5;, score=0.144 total time=   0.0s
# [CV 1/5] END ..................C=100, gamma=0.1;, score=0.571 total time=   0.0s
# [CV 2/5] END ..................C=100, gamma=0.1;, score=0.626 total time=   0.0s
# [CV 3/5] END ..................C=100, gamma=0.1;, score=0.635 total time=   0.0s
# [CV 4/5] END ..................C=100, gamma=0.1;, score=0.346 total time=   0.0s
# [CV 5/5] END ..................C=100, gamma=0.1;, score=0.399 total time=   0.0s
# [CV 1/5] END .................C=100, gamma=0.01;, score=0.659 total time=   0.0s
# [CV 2/5] END .................C=100, gamma=0.01;, score=0.718 total time=   0.0s
# [CV 3/5] END .................C=100, gamma=0.01;, score=0.685 total time=   0.0s
# [CV 4/5] END .................C=100, gamma=0.01;, score=0.152 total time=   0.0s
# [CV 5/5] END .................C=100, gamma=0.01;, score=0.537 total time=   0.0s
# [CV 1/5] END ................C=100, gamma=0.001;, score=0.757 total time=   0.0s
# [CV 2/5] END ................C=100, gamma=0.001;, score=0.730 total time=   0.0s
# [CV 3/5] END ................C=100, gamma=0.001;, score=0.811 total time=   0.0s
# [CV 4/5] END ................C=100, gamma=0.001;, score=0.610 total time=   0.0s
# [CV 5/5] END ................C=100, gamma=0.001;, score=0.725 total time=   0.0s
# [CV 1/5] END ....................C=500, gamma=1;, score=0.124 total time=   0.0s
# [CV 2/5] END ....................C=500, gamma=1;, score=0.123 total time=   0.0s
# [CV 3/5] END ....................C=500, gamma=1;, score=0.093 total time=   0.0s
# [CV 4/5] END ....................C=500, gamma=1;, score=0.111 total time=   0.0s
# [CV 5/5] END ....................C=500, gamma=1;, score=0.064 total time=   0.0s
# [CV 1/5] END ..................C=500, gamma=0.5;, score=0.281 total time=   0.0s
# [CV 2/5] END ..................C=500, gamma=0.5;, score=0.284 total time=   0.0s
# [CV 3/5] END ..................C=500, gamma=0.5;, score=0.239 total time=   0.0s
# [CV 4/5] END ..................C=500, gamma=0.5;, score=0.199 total time=   0.0s
# [CV 5/5] END ..................C=500, gamma=0.5;, score=0.144 total time=   0.0s
# [CV 1/5] END ..................C=500, gamma=0.1;, score=0.571 total time=   0.0s
# [CV 2/5] END ..................C=500, gamma=0.1;, score=0.626 total time=   0.0s
# [CV 3/5] END ..................C=500, gamma=0.1;, score=0.635 total time=   0.0s
# [CV 4/5] END ..................C=500, gamma=0.1;, score=0.346 total time=   0.0s
# [CV 5/5] END ..................C=500, gamma=0.1;, score=0.399 total time=   0.0s
# [CV 1/5] END .................C=500, gamma=0.01;, score=0.659 total time=   0.0s
# [CV 2/5] END .................C=500, gamma=0.01;, score=0.671 total time=   0.0s
# [CV 3/5] END .................C=500, gamma=0.01;, score=0.684 total time=   0.0s
# [CV 4/5] END .................C=500, gamma=0.01;, score=0.152 total time=   0.0s
# [CV 5/5] END .................C=500, gamma=0.01;, score=0.537 total time=   0.0s
# [CV 1/5] END ................C=500, gamma=0.001;, score=0.753 total time=   0.0s
# [CV 2/5] END ................C=500, gamma=0.001;, score=0.731 total time=   0.0s
# [CV 3/5] END ................C=500, gamma=0.001;, score=0.743 total time=   0.0s
# [CV 4/5] END ................C=500, gamma=0.001;, score=0.613 total time=   0.0s
# [CV 5/5] END ................C=500, gamma=0.001;, score=0.642 total time=   0.0s
# SVR(C=50, gamma=0.001)

# %%
svr_new=SVR(C=50,degree=3, epsilon=0.1, gamma=0.001,kernel='rbf')

# %%
svr_new.fit(train_x, train_y)
# Out:
# SVR(C=50, gamma=0.001)

# %%
score_new= r2_score(test_y,svr_new.predict(test_x))
print(score_new)
# Out:
# 0.7457021772643667
